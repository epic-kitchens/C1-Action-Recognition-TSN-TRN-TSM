# %% [markdown]
# # Dataset demonstration
#
# This notebook shows you how to read the data using GulpIO and visualise the frames (both RGB and optical flow U/V pairs).

# %%
from gulpio2 import GulpDirectory
from pathlib import Path
from moviepy.editor import ImageSequenceClip, clips_array
import numpy as np

# %%
gulp_root = Path.home()

# %%
rgb_train = GulpDirectory('/home/will/P01_rgb_gulp')

# %%
flow_train = GulpDirectory('/home/will/P01_flow_gulp/')

# %%
clip_id = 'P01_103_96'

# %%
rgb_frames, rgb_meta = rgb_train[clip_id]

# %%
flow_frames, flow_meta = flow_train[clip_id]

# %%
def display_rgb(rgb_frames, fps=50):
    return ImageSequenceClip(rgb_frames, fps=fps)

# %%
def display_flow(flow_frames, fps=50):
    u_frames = flow_frames[::2]
    v_frames = flow_frames[1::2]
    
    def flow_to_clip(flow):
        # Convert optical flow magnitude to greyscale RGB
        return ImageSequenceClip(list(np.stack([flow] * 3, axis=-1)), fps=fps)
    
    u_clip = flow_to_clip(u_frames) 
    v_clip = flow_to_clip(v_frames) 
    return clips_array([[u_clip, v_clip]])

# %%
clips_array([[display_rgb(rgb_frames), display_flow(flow_frames)]]).ipython_display()
# Out:
# t:  14%|█▎        | 8/59 [00:00<00:00, 78.54it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
rgb_meta
# Out:
# {'narration_id': 'P01_06_92',
#  'participant_id': 'P01',
#  'video_id': 'P01_06',
#  'narration_timestamp': '00:05:44.979',
#  'start_timestamp': '00:05:44.05',
#  'stop_timestamp': '00:05:45.00',
#  'start_frame': 20643,
#  'stop_frame': 20700,
#  'narration': 'take sponge',
#  'verb': 'take',
#  'verb_class': 0,
#  'noun': 'sponge',
#  'noun_class': 9,
#  'all_nouns': ['sponge'],
#  'all_noun_classes': [9],
#  'frame_size': [256, 456, 3],
#  'num_frames': 58}

# %%
clip_id = 'P01_06_90'

# %%
rgb_frames, rgb_meta = rgb_train[clip_id]

# %%
flow_frames, flow_meta = flow_train[clip_id]

# %%
clips_array([[display_rgb(rgb_frames, fps=60), display_flow(flow_frames, fps=30)]]).ipython_display()
# Out:
# t:  16%|█▌        | 8/51 [00:00<00:00, 78.70it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
rgb_meta
# Out:
# {'narration_id': 'P01_06_90',
#  'participant_id': 'P01',
#  'video_id': 'P01_06',
#  'narration_timestamp': '00:05:42.000',
#  'start_timestamp': '00:05:41.40',
#  'stop_timestamp': '00:05:42.22',
#  'start_frame': 20484,
#  'stop_frame': 20533,
#  'narration': 'put fork',
#  'verb': 'put',
#  'verb_class': 1,
#  'noun': 'fork',
#  'noun_class': 14,
#  'all_nouns': ['fork'],
#  'all_noun_classes': [14],
#  'frame_size': [256, 456, 3],
#  'num_frames': 50}
